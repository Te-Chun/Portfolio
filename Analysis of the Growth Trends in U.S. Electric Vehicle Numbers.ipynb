# %% [raw]
# IMPORTINGS

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [raw]
# READ DATASET

# %%
data = pd.read_csv("Downloads/Electric_Vehicle_Population_Size_History_By_County_.csv")
data.sample(10)
# Out:
#                     Date     County State Vehicle Primary Use  \
# 1778        July 31 2020     Shelby    OH           Passenger
# 18915   November 30 2021  San Mateo    CA           Passenger
# 8432     October 31 2018       Lake    CA           Passenger
# 11786  September 30 2020   Williams    ND           Passenger
# 9578     January 31 2017     Juneau    AK           Passenger
# 7142    November 30 2019  Berkshire    MA           Passenger
# 5303         May 31 2022       Kern    CA           Passenger
# 10084       July 31 2021  Champaign    IL           Passenger
# 6819    December 31 2017     Howard    MD           Passenger
# 1618     January 31 2020    Suffolk    VA           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 1778                                 0
# 18915                                2
# 8432                                 0
# 11786                                0
# 9578                                 0
# 7142                                 0
# ...
